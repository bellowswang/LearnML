# %%
import pandas as pd
import numpy as np
import torch

# %%
x = torch.rand(5, 3)
print(x)
# Out:
# tensor([[0.7886, 0.3799, 0.0197],
#         [0.7111, 0.4431, 0.0702],
#         [0.5718, 0.0983, 0.9953],
#         [0.2484, 0.1117, 0.1312],
#         [0.6859, 0.8836, 0.6610]])
